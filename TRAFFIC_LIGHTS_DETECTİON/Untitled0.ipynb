# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/YoloV8/TRAFFIC_LIGHTS_DETECTİON
# Out:
# /content/drive/MyDrive/YoloV8/TRAFFIC_LIGHTS_DETECTİON

# %%
#paketi indir
# %pip install ultralytics
import  ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.5/112.6 GB disk)

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/YoloV8/TRAFFIC_LIGHTS_DETECTİON'

# %%
# !yolo detect train data=/content/drive/MyDrive/YoloV8/TRAFFIC_LIGHTS_DETECTİON/Data/config_new.yaml model=yolov8n.pt epochs=50 workers=8 batch=8 device=0 name=yolov8_traffic_light_detectionnn
# Out:
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect predict model=runs/detect/yolov8_traffic_light_detectionnn2/weights/best.pt source=inference save=True
# Out:
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/121 /content/drive/MyDrive/YoloV8/TRAFFIC_LIGHTS_DETECTİON/inference/Tlight-583-_png_jpg.rf.2a798c83adb4ca546dced0bc5c79953c.jpg: 640x640 (no detections), 7.5ms
# image 2/121 /content/drive/MyDrive/YoloV8/TRAFFIC_LIGHTS_DETECTİON/inference/Tlight-583-_png_jpg.rf.56fb9403cbf5a905e760cb7dfb696d1e.jpg: 640x640 (no detections), 9.8ms
# image 3/121 /content/drive/MyDrive/YoloV8/TRAFFIC_LIGHTS_DETECTİON/inference/Tlight-583-_png_jpg.rf.f93003f8559ab3b671be53fb1061aa30.jpg: 640x640 (no detections), 11.2ms
# image 4/121 /content/drive/MyDrive/YoloV8/TRAFFIC_LIGHTS_DETECTİON/inference/Tlight-778-_png_jpg.rf.298d5f5c16f7b2f6f5039cdd21bec4c0.jpg: 640x640 1 traffic-lights, 9.5ms
# ...
